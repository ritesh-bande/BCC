# %%
mylist=["prashant","ashish","komal","ankush",77,"sandip",60.52,"prashant"]
print(mylist)
print(mylist[1])
print(mylist[-1])
print(mylist[2:5])
print(mylist[:5])
print(mylist[1:8:2])
print(mylist[:])
print(mylist[::-1])

# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
mylist.append('harsh')
mylist.append('lax')
mylist.insert(1,"sanket")
mylist.remove("sandip")
newlist=mylist.copy()
print(newlist)
print(mylist)

# %%
mylist=[['prashant','jha'],['85.56'],[440022,"yyy"]]
print("example of multidimensional list")
print(mylist)
print(mylist[0][0])
print(mylist[0][1])
print(mylist[1][0])
print(mylist[2][0])
print(mylist[2][1])

# %%
list1=["prashant","jha"]
print(list1*2)
list2=[50,25.50,'prashant']
del list2[2]
list2.clear()

print(list2)

# %%
name="prashant"
print(name)
myname=list(name)
print(myname)

# %%
mylist=[44,22,77,0,9,8]
mylist.sort(reverse=True)
print(mylist)

# %%
print("hi")

# %%
math=10
phy=10
print(id(math))
print(id(phy))

# %%
mylist=[44,22,77,0,9,8]
newlist=mylist
print(id(mylist))
print(id(newlist))

# %%
# there are two type os specia l operator
# menmbership=in and not in and 
name='prashant'
print('z'not in name)

# %%
for i in range(1,10,3):
    print(i)

# %%
for i in range(5,0,-1):
    print(i)

# %%
for i in range(1,12):
    print(i*2, i*3, i*4, i*5, i*6, i*7, i*8, i*9, i*10 )
    print()
for i in range(10,20):
    print(  i*11, i*12, i*13, i*14, i*15, i*16, i*17, i*18, i*19)

# %%
marks1=int(input("Enter your 1st paper marks:")
marks2=int(input("Enter your 2nd paper marks:")
marks3=int(input("Enter your 3rd paper marks:")
total=marks1+marks2+marks3/3*100
if(total>60 or total=60):
    print("eligible for placements")
else:
    print("not eligible")
