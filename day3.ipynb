# %%
mydict={
    101:"prashant",
    "professional":"developer",
    "empid":11001
}
mydict.pop(101)
print(mydict)

print(type(mydict))
# Out:
# {'professional': 'developer', 'empid': 11001}
# <class 'dict'>

# %%
mydict={
    101:"prashant",
    102:"ashish",
    "103":"triveni",
    "104":"mohini",
    101:"ashish",
    104:"ashish"
}
a=mydict[102]
print(a)
print(mydict)
mydict[102]="peter"
print(mydict)
# for x in mydict:
  # print(x)
#
# for x,y in mydict.items():
#   print(x,y)
mydict["mobile_no"]=46788898
print(mydict)
# Out:
# ashish
# {101: 'ashish', 102: 'ashish', '103': 'triveni', '104': 'mohini', 104: 'ashish'}
# {101: 'ashish', 102: 'peter', '103': 'triveni', '104': 'mohini', 104: 'ashish'}
# {101: 'ashish', 102: 'peter', '103': 'triveni', '104': 'mohini', 104: 'ashish', 'mobile_no': 46788898}

# %%
name="prashantjha"
print(name[0])
print(name[0:5])
print(name[1:])
print(name[:5])
print(name[:])
print(name[1:8:2])
print(name[::-1])
# Out:
# p
# prash
# rashantjha
# prash
# prashantjha
# rsat
# ahjtnahsarp

# %%
s="helpcode is best platform for programming practice"
print(s.find("helpcode"))
print(s.find("best"))
# Out:
# 0
# 12

# %%
s="prashant","sandip","ashish"
m='|'.join(s)
print(m)
# Out:
# prashant|sandip|ashish

# %%
s="Python is a High level programming language"
print(s.lower())
print(s.swapcase())
print(s.title())
# Out:
# python is a high level programming language
# pYTHON IS A hIGH LEVEL PROGRAMMING LANGUAGE
# Python Is A High Level Programming Language

# %%
print('subject marks')
phy=50
chem=60
math=70
print("physics={} chemistry{} Math={} ".format(phy,chem,math))
print("physics={0} chemistry{1} Math={2} ".format(phy,chem,math))
print("physics={x} chemistry{y} Math={z} ".format(x=phy,y=chem,z=math))
total=phy+chem+math
print(f"{total}")
# Out:
# subject marks
# physics=50 chemistry60 Math=70
# physics=50 chemistry60 Math=70
# physics=50 chemistry60 Math=70
# 180

# %%
a=50
b=30
c=20
d=10
print((a+b)*c/d)
print((a-b)*(c/d))
print(a+(b*c)/d)
# Out:
# 160.0
# 40.0
# 110.0

# %%
name="prashant"
count=0
consonant=0
for i in name:
  if(i=="a" and "e" and "i" and "o" and "u"):
    count+=1

  else:
    consonant+=1

print("no of vowel is",count)
print("no of consonant is ",consonant)
# Out:
# no of vowel is 2
# no of consonant is  6
