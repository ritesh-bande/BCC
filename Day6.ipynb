# %%
fruit_list=['apple','berry','cherry','papaya']
fruit_list2=fruit_list#address same so elements will also be changed in both
fruit_list3=fruit_list[:]
fruit_list2[0]='Guava'
fruit_list3[1]='kiwi'

sum=0
for ls in(fruit_list,fruit_list2,fruit_list3):
  if ls[0]=='Guava':
    sum+=1
  if ls[1]=='kiwi':
    sum+=20
print(sum)
# Out:
# 22

# %%
def f(i,values=[]):
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
def func(value,values):
    var=1
    values[0]=44
t=3
v=[1,2,3]
func(t,v)
print(t,v[0])
# Out:
# 3 44

# %%
fruit={}
def addone(index):
  if index in fruit:
    fruit[index]+=1
  else:
    fruit[index]=1
addone("apple")
addone('Banana')
addone('Apple')
print(len(fruit))
# Out:
# 3

# %%
l1=[1,2,3,4]
l2=[]

for i in range(len(l1)-1,-1,-1):
  for j in range(len(l1)-1):
    if(i==j):
      pass
    else:
      print(l1[j]*l1[i-1])
# Out:
# 3
# 6
# 9
# 2
# 4
# 1
# 3
# 8
# 12
